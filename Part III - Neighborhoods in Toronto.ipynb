# %% [markdown]
# The following cell contains secret credentials:

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# 20190530

# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
# # Part III
#
# In part I and II we aquired and prepared the data we need to analyse the neighborhoods of Toronto. In this part we enlarge our dataset with the information on venues in range of each neighborhood. Then we will visualize the data to gain insights.
#
# First, let's get our environment ready:

# %%
# !conda install -c conda-forge folium --quiet
# !conda install -c conda-forge geocoder --quiet
# Out:
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import folium
import geocoder
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from itertools import combinations
from geopy.distance import distance, great_circle

# %% [markdown]
# Now, let's import the dataset from part II:

# %%
# Read the csv file we created before; "project.get_file()" is Watson Studio specific
df_toronto = pd.read_csv(project.get_file('toronto_final.csv'))
df_toronto.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ## Visualize the neighborhoods

# %%
# Get the coordinates of Toronto per Mapquest-API
g = geocoder.mapquest('Toronto, Canada', key=MAPQUEST_API_KEY)
    
if g.ok:
    toronto_coordinates = tuple([g.latlng[0], g.latlng[1]])
    print('The geographical coordinates of Toronto are {}, {}.'.format(toronto_coordinates[0], toronto_coordinates[1]))
else:
    print('Something went wrong while getting Toronto\'s coordinates.')
# Out:
# The geographical coordinates of Toronto are 43.651893, -79.381713.

# %%
# Create a map of the world centered around Toronto
map_toronto = folium.Map(location=toronto_coordinates, zoom_start=11)

# Add markers of all neighborhoods to the map
for lat, lng, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Neighbourhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        popup=label,
        color='darkblue',
        fill=True,
        fill_color='lightblue',
        fill_opacity=0.5,
        parse_html=False).add_to(map_toronto)

# display map
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Aquire data on venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000, LIMIT=100):
    '''Get information on venues in range of a given coordinate through Foursquare Developer API'''
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        
        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
        
    return(nearby_venues)

# %%
def great_circle_dist(latlon1, latlon2):
    """Uses geopy to calculate distance between coordinates"""
    return great_circle(latlon1, latlon2).meters

def find_nearest(x):
        """Finds nearest neighbor """
        df_distances['distances'] = df_distances.coordinates.apply(great_circle_dist, args=(x,))
        df_distances_sort = df_distances.sort_values(by='distances')
        return (df_distances_sort.values[1][0], df_distances_sort.values[1][2])

coord_list = list(zip(df_toronto['Latitude'], df_toronto['Longitude']))
df_distances = pd.DataFrame({'postcode': df_toronto['Postcode'], 'coordinates': coord_list}, columns=['postcode', 'coordinates'])
    
df_distances['nearest'] = df_distances['coordinates'].apply(find_nearest)
df_distances['distance'] = df_distances.nearest.apply(lambda x: x[1])
del df_distances['nearest']
del df_distances['distances']

display(df_distances.head())
print('The average distance between the all neighborhoods and their nearest neighbor is {0:.2f} meters.'.format(df_distances['distance'].mean()))
# Out:
#   postcode                       coordinates     distance
# 0      M1B  (43.8066863, -79.19435340000003)  3397.205462
# 1      M1C  (43.7845351, -79.16049709999999)  3251.309804
# 2      M1E         (43.7635726, -79.1887115)  2411.191341
# 3      M1G  (43.7709921, -79.21691740000001)  1827.453921
# 4      M1H   (43.773136, -79.23947609999998)  1827.453921
# The average distance between the all neighborhoods and their nearest neighbor is 1786.57 meters.

# %%
# Create dataframe with venues of the region
toronto_venues = getNearbyVenues(names=df_toronto['Neighbourhood'],
                                 latitudes=df_toronto['Latitude'],
                                 longitudes=df_toronto['Longitude'],
                                 radius=890
                                )
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens, Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# Downsview, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Islington Avenue
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Humber Summit
# Emery, Humberlea
# Weston
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# Northwest

# %% [markdown]
# ## Examine the data on venues

# %%
print("The size of the venues dataframe: {}".format(toronto_venues.shape))
toronto_venues.head()
# Out:
# The size of the venues dataframe: (4288, 7)
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Rouge, Malvern              43.806686              -79.194353
# 1  Rouge, Malvern              43.806686              -79.194353
# 2  Rouge, Malvern              43.806686              -79.194353
# 3  Rouge, Malvern              43.806686              -79.194353
# 4  Rouge, Malvern              43.806686              -79.194353
#
#                  Venue  Venue Latitude  Venue Longitude  \
# 0   Images Salon & Spa       43.802283       -79.198565
# 1  Staples Morningside       43.800285       -79.196607
# 2              Wendy's       43.802008       -79.198080
# 3              Wendy's       43.807448       -79.199056
# 4             Harvey's       43.800106       -79.198258
#
#                   Venue Category
# 0                            Spa
# 1  Paper / Office Supplies Store
# 2           Fast Food Restaurant
# 3           Fast Food Restaurant
# 4           Fast Food Restaurant

# %%
print('Count of venues per neighborhood:')
toronto_venues.groupby('Neighborhood')['Venue'].count()
# Out:
# Count of venues per neighborhood:
# Neighborhood
# Adelaide, King, Richmond                                                                                         100
# Agincourt                                                                                                         39
# Agincourt North, L'Amoreaux East, Milliken, Steeles East                                                          25
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown     16
# Alderwood, Long Branch                                                                                            14
# Bathurst Manor, Downsview North, Wilson Heights                                                                   26
# Bayview Village                                                                                                   13
# Bedford Park, Lawrence Manor East                                                                                 44
# Berczy Park                                                                                                      100
# Birch Cliff, Cliffside West                                                                                       12
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe                                                     14
# Brockton, Exhibition Place, Parkdale Village                                                                     100
# Business Reply Mail Processing Centre 969 Eastern                                                                 36
# CFB Toronto, Downsview East                                                                                       14
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara        20
# Cabbagetown, St. James Town                                                                                       33
# Caledonia-Fairbanks                                                                                               25
# Canada Post Gateway Processing Centre                                                                             55
# Cedarbrae                                                                                                         28
# Central Bay Street                                                                                               100
# Chinatown, Grange Park, Kensington Market                                                                        100
# Christie                                                                                                          96
# Church and Wellesley                                                                                             100
# Clairlea, Golden Mile, Oakridge                                                                                   20
# Clarks Corners, Sullivan, Tam O'Shanter                                                                           18
# Cliffcrest, Cliffside, Scarborough Village West                                                                    7
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park                                            17
# Commerce Court, Victoria Hotel                                                                                   100
# Davisville                                                                                                       100
# Davisville North                                                                                                  87
#                                                                                                                 ...
# Northwest                                                                                                          3
# Northwood Park, York University                                                                                   23
# Parkdale, Roncesvalles                                                                                            89
# Parkwoods                                                                                                         16
# Rosedale                                                                                                          15
# Roselawn                                                                                                           5
# Rouge, Malvern                                                                                                    12
# Runnymede, Swansea                                                                                                68
# Ryerson, Garden District                                                                                         100
# Scarborough Village                                                                                                9
# Silver Hills, York Mills                                                                                           2
# St. James Town                                                                                                   100
# Stn A PO Boxes 25 The Esplanade                                                                                  100
# Studio District                                                                                                  100
# The Annex, North Midtown, Yorkville                                                                              100
# The Beaches                                                                                                       60
# The Beaches West, India Bazaar                                                                                    64
# The Danforth West, Riverdale                                                                                     100
# The Junction North, Runnymede                                                                                     37
# The Kingsway, Montgomery Road, Old Mill North                                                                     40
# Thorncliffe Park                                                                                                  33
# Victoria Village                                                                                                   8
# Westmount                                                                                                         11
# Weston                                                                                                            12
# Willowdale South                                                                                                 100
# Willowdale West                                                                                                    7
# Woburn                                                                                                             4
# Woodbine Gardens, Parkview Hill                                                                                   18
# Woodbine Heights                                                                                                  25
# York Mills West                                                                                                   11
# Name: Venue, Length: 101, dtype: int64

# %%
print('There are {} unique categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 329 unique categories.

# %%
# One hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# Rename column
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

# Group by Neighborhood and calculate mean occurence of each Venue Category
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# ### Most common venues per neighborhood

# %%
def return_most_common_venues(row, num_top_venues):
    '''Return the most common venues of a given column of a dataframe'''
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for idx in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(idx+1, indicators[idx]))
    except:
        columns.append('{}th Most Common Venue'.format(idx+1))
        
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for idx in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[idx, 1:] = return_most_common_venues(toronto_grouped.iloc[idx, :], num_top_venues)
    
neighborhoods_venues_sorted.head(12)
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                            Adelaide, King, Richmond           Coffee Shop
# 1                                           Agincourt    Chinese Restaurant
# 2   Agincourt North, L'Amoreaux East, Milliken, St...    Chinese Restaurant
# 3   Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 4                              Alderwood, Long Branch        Discount Store
# 5     Bathurst Manor, Downsview North, Wilson Heights           Pizza Place
# 6                                     Bayview Village                  Bank
# 7                   Bedford Park, Lawrence Manor East    Italian Restaurant
# 8                                         Berczy Park           Coffee Shop
# 9                         Birch Cliff, Cliffside West                  Park
# 10  Bloordale Gardens, Eringate, Markland Wood, Ol...     Fish & Chips Shop
# 11       Brockton, Exhibition Place, Parkdale Village           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue      4th Most Common Venue  \
# 0                   Café                 Hotel        American Restaurant
# 1          Shopping Mall                Bakery                Supermarket
# 2                   Park           Pizza Place          Korean Restaurant
# 3            Pizza Place  Fast Food Restaurant                   Pharmacy
# 4            Pizza Place           Gas Station                   Pharmacy
# 5            Coffee Shop              Pharmacy  Middle Eastern Restaurant
# 6    Japanese Restaurant  Fast Food Restaurant              Grocery Store
# 7   Fast Food Restaurant           Coffee Shop           Sushi Restaurant
# 8                   Café            Restaurant                      Hotel
# 9        College Stadium                   Gym             Discount Store
# 10         Grocery Store                  Bank              Shopping Mall
# 11                  Café                   Bar     Furniture / Home Store
#
#       5th Most Common Venue
# 0                 Gastropub
# 1       Shanghai Restaurant
# 2                    Bakery
# 3              Liquor Store
# 4              Skating Rink
# 5        Frozen Yogurt Shop
# 6              Intersection
# 7   Comfort Food Restaurant
# 8       Japanese Restaurant
# 9                      Café
# 10             Liquor Store
# 11               Restaurant

# %% [markdown]
# ## Cluster the Neighborhoods

# %% [markdown]
# ### Find optimal number of clusters for K-Means Classification Model

# %%
# Determine optimal value of k (quantity of clusters)
from sklearn.metrics import silhouette_score

sum_of_squared_distances = []
sil_coeff = []

X = toronto_grouped.drop('Neighborhood', 1)
K = range(2,21)

for k in K:
    km = KMeans(n_clusters=k, random_state=1)
    km.fit(X)
    sil_coeff.append(silhouette_score(X, km.labels_, metric='euclidean'))
    sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('Number of clusters')
plt.xticks(np.arange(1, len(K)+1, 1.0))
plt.ylabel('Sum of squared distances')
plt.title('Elbow Curve Method to find optimal k')
plt.show()

# %%
plt.plot(K, sil_coeff, 'bx-')
plt.xlabel('Number of clusters')
plt.xticks(np.arange(1, len(K)+1, 1.0))
plt.ylabel('Silhoette Coefficient')
plt.title('Silhouette Score to find optimal k')
plt.show()

# %% [markdown]
# ### Build and train Clustering Model

# %%
kclusters = 10
kmeans_model = KMeans(n_clusters=kclusters, random_state=1)
kmeans_model.fit(toronto_grouped.drop('Neighborhood', 1))
kmeans_model.labels_
# Out:
# array([2, 2, 2, 4, 4, 2, 5, 2, 2, 5, 5, 2, 2, 2, 2, 2, 5, 2, 2, 2, 2, 2, 2,
#        9, 4, 4, 5, 2, 2, 2, 2, 2, 2, 2, 2, 2, 8, 4, 5, 9, 4, 2, 9, 2, 2, 2,
#        2, 4, 4, 2, 2, 2, 2, 6, 5, 2, 3, 5, 4, 5, 4, 2, 4, 2, 2, 2, 2, 2, 5,
#        2, 2, 7, 2, 2, 5, 5, 0, 4, 2, 2, 4, 1, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2,
#        5, 4, 4, 2, 4, 7, 4, 4, 5], dtype=int32)

# %% [markdown]
# ### Visualize Clusters

# %%
# Merge datasets
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans_model.labels_)
toronto_merged = df_toronto.rename(columns={'Neighbourhood': 'Neighborhood'})
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood', how='right').reset_index(drop=True)

# How does our combined dataframe look like? 
toronto_merged.head()
# Out:
#   Postcode      Borough                            Neighborhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353               4  Fast Food Restaurant           Coffee Shop
# 1 -79.160497               6          Burger Joint        Breakfast Spot
# 2 -79.188711               4           Pizza Place  Fast Food Restaurant
# 3 -79.216917               7           Coffee Shop               Dog Run
# 4 -79.239476               2                Bakery     Indian Restaurant
#
#   3rd Most Common Venue       4th Most Common Venue    5th Most Common Venue
# 0                   Spa  Construction & Landscaping  Fruit & Vegetable Store
# 1            Playground          Italian Restaurant     Ethiopian Restaurant
# 2           Coffee Shop               Smoothie Shop                     Bank
# 3                  Park                         Zoo      Empanada Restaurant
# 4           Coffee Shop            Asian Restaurant       Athletics & Sports

# %%
# create map
map_clusters = folium.Map(location=toronto_coordinates, zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.viridis(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'],
                                  toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=7,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %%
# How many neighborhoods per Cluster?
toronto_merged['Cluster Labels'].value_counts()
# Out:
# 2    58
# 4    19
# 5    14
# 9     3
# 7     2
# 8     1
# 6     1
# 3     1
# 1     1
# 0     1
# Name: Cluster Labels, dtype: int64

# %%
for i in range(kclusters):
    print('Cluster No. {}'.format(i))
    display(toronto_merged.loc[toronto_merged['Cluster Labels'] == i])
    print('-------------------------------------')
# Out:
# Cluster No. 0
#    Postcode          Borough Neighborhood   Latitude  Longitude  \
# 62      M5N  Central Toronto     Roselawn  43.711695 -79.416936
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 62               0                Garden            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 62          Skating Rink           Music Venue             Pet Store
# -------------------------------------
# Cluster No. 1
#    Postcode     Borough              Neighborhood  Latitude  Longitude  \
# 19      M2L  North York  Silver Hills, York Mills  43.75749 -79.374714
#
#     Cluster Labels 1st Most Common Venue      2nd Most Common Venue  \
# 19               1                  Pool  Middle Eastern Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 19                   Zoo   Empanada Restaurant              Dive Bar
# -------------------------------------
# Cluster No. 2
#    Postcode           Borough  \
# 4       M1H       Scarborough
# 10      M1P       Scarborough
# 11      M1R       Scarborough
# 12      M1S       Scarborough
# 14      M1V       Scarborough
# 17      M2J        North York
# 20      M2M        North York
# 21      M2N        North York
# 25      M3B        North York
# 26      M3C        North York
# 27      M3H        North York
# 28      M3J        North York
# 29      M3K        North York
# 36      M4E      East Toronto
# 37      M4G         East York
# 38      M4H         East York
# 39      M4J         East York
# 40      M4K      East Toronto
# 41      M4L      East Toronto
# 42      M4M      East Toronto
# 43      M4N   Central Toronto
# 44      M4P   Central Toronto
# 45      M4R   Central Toronto
# 46      M4S   Central Toronto
# 48      M4V   Central Toronto
# 50      M4X  Downtown Toronto
# 51      M4Y  Downtown Toronto
# 52      M5A  Downtown Toronto
# 53      M5B  Downtown Toronto
# 54      M5C  Downtown Toronto
# 55      M5E  Downtown Toronto
# 56      M5G  Downtown Toronto
# 57      M5H  Downtown Toronto
# 58      M5J  Downtown Toronto
# 59      M5K  Downtown Toronto
# 60      M5L  Downtown Toronto
# 55                     Restaurant                      Hotel
# 56            Arts & Crafts Store            Bubble Tea Shop
# 57                          Hotel        American Restaurant
# 58                           Café         Italian Restaurant
# 59                           Café                 Restaurant
# 60                           Café                 Restaurant
# 61                    Coffee Shop           Sushi Restaurant
# 63                           Bank                Coffee Shop
# 64  Vegetarian / Vegan Restaurant                Pizza Place
# 65  Vegetarian / Vegan Restaurant                 Restaurant
# 66                            Bar         Mexican Restaurant
# 67                 Airport Lounge            Airport Service
# 68                          Hotel                   Beer Bar
# 69                           Café                 Restaurant
# 70           Fast Food Restaurant         Miscellaneous Shop
# 74                    Coffee Shop              Grocery Store
# 75                           Park                   Pharmacy
# 76                         Bakery                Pizza Place
# 77                            Bar     Furniture / Home Store
# 79     Construction & Landscaping     Furniture / Home Store
# 81             Italian Restaurant              Grocery Store
# 82                 Breakfast Spot           Sushi Restaurant
# 83                    Pizza Place                     Bakery
# 84      Middle Eastern Restaurant                      Hotel
# 85                           Park              Burrito Place
# 86             Italian Restaurant         Mexican Restaurant
# 88              French Restaurant           Sushi Restaurant
# 90           Gym / Fitness Center                  BBQ Joint
#
#         5th Most Common Venue
# 4          Athletics & Sports
# 10                Pizza Place
# 11                Fish Market
# 12        Shanghai Restaurant
# 14                     Bakery
# 17                 Food Court
# 20                Coffee Shop
# 21            Bubble Tea Shop
# 25             Baseball Field
# 26           Asian Restaurant
# 27         Frozen Yogurt Shop
# 28         Chinese Restaurant
# 29  Latin American Restaurant
# 36                     Bakery
# 37               Burger Joint
# 38                Coffee Shop
# 39       Fast Food Restaurant
# 40                       Café
# 41                    Brewery
# 42                      Diner
# 43                      Trail
# 44           Sushi Restaurant
# 45                       Café
# 46             Sandwich Place
# 48                Pizza Place
# 50                      Diner
# 51                 Restaurant
# 52             Cosmetics Shop
# 53             Cosmetics Shop
# 54                 Restaurant
# 55        Japanese Restaurant
# 56        Japanese Restaurant
# 57                  Gastropub
# 58                   Aquarium
# 59                 Steakhouse
# 60        Japanese Restaurant
# 61    Comfort Food Restaurant
# 63         Italian Restaurant
# 64         Italian Restaurant
# 65                Coffee Shop
# 66                     Bakery
# 67           Airport Terminal
# 68                 Restaurant
# 69         Italian Restaurant
# 70               Dessert Shop
# 74          Indian Restaurant
# 75                        Bar
# 76                 Restaurant
# 77                 Restaurant
# 79             Sandwich Place
# 81          Convenience Store
# 82                Pizza Place
# 83         Italian Restaurant
# 84        Fried Chicken Joint
# 85         Italian Restaurant
# 86                     Bakery
# 88             Breakfast Spot
# 90         Italian Restaurant
# -------------------------------------
# Cluster No. 3
#    Postcode    Borough                                       Neighborhood  \
# 89      M8Y  Etobicoke  Humber Bay, King's Mill Park, Kingsway Park So...
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 89  43.636258 -79.498509               3                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 89  Gym / Fitness Center         Shopping Mall    Dim Sum Restaurant
#
#    5th Most Common Venue
# 89        Discount Store
# -------------------------------------
# Cluster No. 4
#    Postcode      Borough                                       Neighborhood  \
# 0       M1B  Scarborough                                     Rouge, Malvern
# 2       M1E  Scarborough                  Guildwood, Morningside, West Hill
# 5       M1J  Scarborough                                Scarborough Village
# 6       M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 8       M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 13      M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# 15      M1W  Scarborough                                    L'Amoreaux West
# 23      M2R   North York                                    Willowdale West
# 32      M3N   North York                                Downsview Northwest
# 34      M4B    East York                    Woodbine Gardens, Parkview Hill
# 35      M4C    East York                                   Woodbine Heights
# 71      M6B   North York                                          Glencairn
# 72      M6C         York                                 Humewood-Cedarvale
# 80      M6N         York                      The Junction North, Runnymede
# 87      M8W    Etobicoke                             Alderwood, Long Branch
# 96      M9N         York                                             Weston
# 97      M9P    Etobicoke                                          Westmount
# 98      M9R    Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 99      M9V    Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0   43.806686 -79.194353               4  Fast Food Restaurant
# 2   43.763573 -79.188711               4           Pizza Place
# 5   43.744734 -79.239476               4  Fast Food Restaurant
# 6   43.727929 -79.262029               4           Coffee Shop
# 8   43.716316 -79.239476               4  Fast Food Restaurant
# 13  43.781638 -79.304302               4           Pizza Place
# 15  43.799525 -79.318389               4  Fast Food Restaurant
# 23  43.782736 -79.442259               4               Butcher
# 32  43.761631 -79.520999               4                 Hotel
# 34  43.706397 -79.309937               4           Pizza Place
# 35  43.695344 -79.318389               4           Coffee Shop
# 71  43.709577 -79.445073               4  Fast Food Restaurant
# 72  43.693781 -79.428191               4           Pizza Place
# 80  43.673185 -79.487262               4           Pizza Place
# 87  43.602414 -79.543484               4        Discount Store
# 96  43.706876 -79.518188               4         Train Station
# 97  43.696319 -79.532242               4           Pizza Place
# 98  43.688905 -79.554724               4        Sandwich Place
# 99  43.739416 -79.588437               4         Grocery Store
#
#    2nd Most Common Venue      3rd Most Common Venue  \
# 0            Coffee Shop                        Spa
# 2   Fast Food Restaurant                Coffee Shop
# 5            Coffee Shop                Pizza Place
# 6     Chinese Restaurant              Grocery Store
# 8            Pizza Place               Burger Joint
# 13         Shopping Mall                   Bus Stop
# 15           Coffee Shop         Chinese Restaurant
# 23           Coffee Shop                Pizza Place
# 32           Pizza Place       Fast Food Restaurant
# 34               Brewery       Fast Food Restaurant
# 35        Sandwich Place            Thai Restaurant
# 71         Grocery Store                Coffee Shop
# 72           Coffee Shop              Grocery Store
# 80                  Park                    Brewery
# 87           Pizza Place                Gas Station
# 96           Coffee Shop                      Diner
# 97        Discount Store  Middle Eastern Restaurant
# 98     Mobile Phone Shop           Business Service
# 99           Pizza Place       Fast Food Restaurant
#
#          4th Most Common Venue      5th Most Common Venue
# 0   Construction & Landscaping    Fruit & Vegetable Store
# 2                Smoothie Shop                       Bank
# 5               Sandwich Place                 Restaurant
# 6               Discount Store                Pizza Place
# 8       Furniture / Home Store                       Park
# 13                 Golf Course               Noodle House
# 15              Sandwich Place          Indian Restaurant
# 23           Convenience Store                   Pharmacy
# 32                    Pharmacy              Grocery Store
# 34              Breakfast Spot         Rock Climbing Spot
# 35                 Pizza Place                       Park
# 71                  Shoe Store  Latin American Restaurant
# 72           Convenience Store             Sandwich Place
# 80                 Coffee Shop             Sandwich Place
# 87                    Pharmacy               Skating Rink
# 96              Breakfast Spot                Pizza Place
# 97                 Coffee Shop             Sandwich Place
# 98                Intersection            Supplement Shop
# 99                    Pharmacy               Liquor Store
# -------------------------------------
# Cluster No. 5
#    Postcode           Borough  \
# 9       M1N       Scarborough
# 16      M2H        North York
# 18      M2K        North York
# 22      M2P        North York
# 24      M3A        North York
# 30      M3L        North York
# 33      M4A        North York
# 47      M4T   Central Toronto
# 49      M4W  Downtown Toronto
# 73      M6E              York
# 91      M9A         Etobicoke
# 92      M9B         Etobicoke
# 93      M9C         Etobicoke
# 94      M9L        North York
#
#                                          Neighborhood   Latitude  Longitude  \
# 9                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 16                                  Hillcrest Village  43.803762 -79.363452
# 18                                    Bayview Village  43.786947 -79.385975
# 22                                    York Mills West  43.752758 -79.400049
# 24                                          Parkwoods  43.753259 -79.329656
# 30                                     Downsview West  43.739015 -79.506944
# 33                                   Victoria Village  43.725882 -79.315572
# 47                        Moore Park, Summerhill East  43.689574 -79.383160
# 49                                           Rosedale  43.679563 -79.377529
# 73                                Caledonia-Fairbanks  43.689026 -79.453512
# 91                                   Islington Avenue  43.667856 -79.532242
# 92  Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 93  Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 94                                      Humber Summit  43.756303 -79.565963
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 9                5                  Park       College Stadium
# 16               5              Pharmacy                  Park
# 18               5                  Bank   Japanese Restaurant
# 22               5                   Gym                  Park
# 24               5                  Park              Bus Stop
# 30               5                  Park         Grocery Store
# 33               5                  Park          Hockey Arena
# 47               5         Grocery Store                  Park
# 49               5                  Park           Coffee Shop
# 73               5                  Park              Pharmacy
# 91               5              Pharmacy           Golf Course
# 92               5                  Bank           Pizza Place
# 93               5     Fish & Chips Shop         Grocery Store
# 94               5   Empanada Restaurant     Electronics Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 9                    Gym        Discount Store                  Café
# 16           Pizza Place   Housing Development                  Bank
# 18  Fast Food Restaurant         Grocery Store          Intersection
# 22           Golf Course                  Bank               Dog Run
# 24         Grocery Store                  Café        Discount Store
# 30                   Spa           Coffee Shop           Pizza Place
# 33           Pizza Place   Sporting Goods Shop          Intersection
# 47            Playground                  Café                  Bank
# 49                  Bank         Grocery Store           Candy Store
# 73           Coffee Shop        Discount Store                  Bank
# 91                  Bank            Playground         Shopping Mall
# 92     Convenience Store                 Hotel                   Gym
# 93                  Bank         Shopping Mall          Liquor Store
# 94                Bakery           Pizza Place                  Park
# -------------------------------------
# Cluster No. 6
#   Postcode      Borough                            Neighborhood   Latitude  \
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1 -79.160497               6          Burger Joint        Breakfast Spot
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 1            Playground    Italian Restaurant  Ethiopian Restaurant
# -------------------------------------
# Cluster No. 7
#     Postcode      Borough Neighborhood   Latitude  Longitude  Cluster Labels  \
# 3        M1G  Scarborough       Woburn  43.770992 -79.216917               7
# 100      M9W    Etobicoke    Northwest  43.706748 -79.594054               7
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 3             Coffee Shop               Dog Run                  Park
# 100               Dog Run           Coffee Shop                 Hotel
#
#     4th Most Common Venue 5th Most Common Venue
# 3                     Zoo   Empanada Restaurant
# 100                   Zoo   Empanada Restaurant
# -------------------------------------
# Cluster No. 8
#    Postcode     Borough       Neighborhood   Latitude  Longitude  \
# 31      M3M  North York  Downsview Central  43.728496 -79.495697
#
#     Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 31               8            Food Truck  Vietnamese Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 31            Restaurant        Baseball Field                   Zoo
# -------------------------------------
# Cluster No. 9
#    Postcode      Borough                        Neighborhood   Latitude  \
# 7       M1L  Scarborough     Clairlea, Golden Mile, Oakridge  43.711112
# 78      M6L   North York  Downsview, North Park, Upwood Park  43.713756
# 95      M9M   North York                    Emery, Humberlea  43.724766
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 7  -79.284577               9          Intersection                 Diner
# 78 -79.490074               9                Bakery           Coffee Shop
# 95 -79.532242               9                Bakery           Golf Course
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 7               Bus Line           Coffee Shop                Bakery
# 78                  Park     Convenience Store                   Zoo
# 95     Convenience Store          Intersection                  Park
# -------------------------------------
